# %% [markdown]
# ## 월간 인재경영 크롤링

# %%
import requests # 원격 서버 data 요청
from bs4 import BeautifulSoup # html parser

url = "http://www.abouthr.co.kr/"

# %%
# 1. url 요청
req = requests.get(url)
print(req) # 
src = req.text # text형식으로
# Out:
# <Response [200]>

# %%
# 2. html 파싱
html = BeautifulSoup(src, "html.parser")
html
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=1080" name="viewport"/>
# <meta content="월간 인재경영" name="apple-mobile-web-app-title">
# <!-- 메타태그정보 //-->
# <meta content="월간 인재경영 공식 사이트, 국내외 최신 HR 정보 및 칼럼 수록, 월간 인재경영 정기구독 신청" name="description">
# <meta content="월간 인재경영" property="og:title">
# <meta content="월간 인재경영" property="og:site_name"/>
# <meta content="http://www.abouthr.co.kr/image/logo/snslogo_20201105032439.jpg" property="og:image"/>
# <meta content="http://www.abouthr.co.kr" property="og:url"/>
# <meta content="월간 인재경영 공식 사이트, 국내외 최신 HR 정보 및 칼럼 수록, 월간 인재경영 정기구독 신청" property="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="월간 인재경영" name="twitter:title"/>
# <meta content="월간 인재경영 공식 사이트, 국내외 최신 HR 정보 및 칼럼 수록, 월간 인재경영 정기구독 신청" name="twitter:description"/>
# ...

# %%
# 3. tag[속성='값']
links = html.select("span[class]")
links = links[6:-14]
len(links)
# Out:
# 209

# %%
# 4. tag 내용 수집
crawling_data = []

for a in links :
    #print(a.string)
    cont = a.string
    if cont : # None 제외
        cont = str(cont)
        # strip() : 문장 끝 불용어 제거
        crawling_data.append(cont.strip())
        
crawling_data
# Out:
# ['2023년 국내 기업 HR 방향',
#  '임직원 리스킬·업스킬의  필요성과 전망',
#  '기업 ESG경영, “안전·인권·윤리의 올바른 길을 향해”',
#  '실리콘밸리 기업의 2023 HR 키워드',
#  '대퇴사 시대 인사관리, “어떤 기대를 갖고 일하게 만들 것인가?”',
#  '2023 한국 채용매력지수 1위...한국전력, 동화기업, 한국중부발전',
#  '대퇴사와 조용한 퇴직이 기업을 둘러싼 인사 이슈로 떠오르면서, 우수 인재 채용을 위한 기업의 브랜딩 전략과 구성원들이 자부심을 갖고 행복하게 일하는 근무환경 조성이 필수 과제로 떠오르고 있다.구성원이 즐겁게 일함으로써 기업이 성장하고, 인재들이 오고 싶은 회사로 발전하...',
#  '‘Zero百’을 향해 나아가는 실리콘밸리 HR 연구회',
#  '미국 캘리포니아의 날씨가 제법 쌀쌀해지고 사람들은 집집마다 성탄 트리를 준비하기 시작했던 2022년 12월, 실리콘밸리 HR 연구회도 올해를 마무리하고 다가오는 2023년을 준비하기 위해 2022년 6차 정기 모임을 가졌다. 이번 모임은 SK 하이닉스 미주법인 Miss...',
#  '인적자본 확충이 경쟁력의 원천이다',
#  '인적자원 관리에서 인적자본 경영으로의 이행최근 일본에서는 인적자원 관리(Human Resource Management)보다 인적자본 경영(Human Capital Management)이란 용어가 널리 사용되고 있다. 인적자본(人的資本)이란 인재가 교육이나 연수, 일상 ...',
#  '리세션 시대의 HR',
#  '리세션(Recession; 경기침체, 불황) 공포가 커지고 있다. 리세션은 경기가 활기를 잃어 전반적으로 축소되는 현상을 말한다. 미 경제조사국 NBER(National Bureau of Economic Research)에서는 실질 GDP가 2분기 연속 감소하면 리세션...',
#  'TIME 誌 ‘올해의 인물’로  점쳐보는 계묘년 인사',
# ...

# %%
#Dataframe으로 만들기
import pandas as pd
df = pd.DataFrame({'내용':crawling_data})

#df 저장
df.to_csv('crawl.txt',encoding='utf-8',index=False)

# %% [markdown]
# ## 형태소 분석

# %%
file = open("crawl.txt", mode='r', encoding='utf-8')
doc = file.read()
file.close()
doc
# Out:
# '내용\n2023년 국내 기업 HR 방향\n임직원 리스킬·업스킬의  필요성과 전망\n"기업 ESG경영, “안전·인권·윤리의 올바른 길을 향해”"\n실리콘밸리 기업의 2023 HR 키워드\n"대퇴사 시대 인사관리, “어떤 기대를 갖고 일하게 만들 것인가?”"\n"2023 한국 채용매력지수 1위...한국전력, 동화기업, 한국중부발전"\n"대퇴사와 조용한 퇴직이 기업을 둘러싼 인사 이슈로 떠오르면서, 우수 인재 채용을 위한 기업의 브랜딩 전략과 구성원들이 자부심을 갖고 행복하게 일하는 근무환경 조성이 필수 과제로 떠오르고 있다.구성원이 즐겁게 일함으로써 기업이 성장하고, 인재들이 오고 싶은 회사로 발전하..."\n‘Zero百’을 향해 나아가는 실리콘밸리 HR 연구회\n"미국 캘리포니아의 날씨가 제법 쌀쌀해지고 사람들은 집집마다 성탄 트리를 준비하기 시작했던 2022년 12월, 실리콘밸리 HR 연구회도 올해를 마무리하고 다가오는 2023년을 준비하기 위해 2022년 6차 정기 모임을 가졌다. 이번 모임은 SK 하이닉스 미주법인 Miss..."\n인적자본 확충이 경쟁력의 원천이다\n"인적자원 관리에서 인적자본 경영으로의 이행최근 일본에서는 인적자원 관리(Human Resource Management)보다 인적자본 경영(Human Capital Management)이란 용어가 널리 사용되고 있다. 인적자본(人的資本)이란 인재가 교육이나 연수, 일상 ..."\n리세션 시대의 HR\n"리세션(Recession; 경기침체, 불황) 공포가 커지고 있다. 리세션은 경기가 활기를 잃어 전반적으로 축소되는 현상을 말한다. 미 경제조사국 NBER(National Bureau of Economic Research)에서는 실질 GDP가 2분기 연속 감소하면 리세션..."\nTIME 誌 ‘올해의 인물’로  점쳐보는 계묘년 인사\n"강력한 공감대를 만드는 스토리텔링은 마케팅뿐 아니라 모든 경영활동에서 그대로 빛을 발한다. 스토리의 주인공, 즉 인물이 누구인지도 성공적인 스토리텔링의 키포인
# ...

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
ex_sent = kkma.sentences(doc)
ex_sent
# Out:
# ['내용 2023년 국내 기업 HR 방향 임직원 리 스킬· 업 스킬의 필요성과 전망 " 기업 ESG 경영, “ 안전· 인권· 윤리의 올바른 길을 향해”" 실리콘 밸리 기업의 2023 HR 키워드 " 대퇴사 시대 인사관리, “ 어떤 기대를 갖고 일하게 만들 것인가?',
#  '”" "2023 한국 채용 매력지수 1위... 한국 전력, 동화기업, 한국 중부 발전" " 대퇴사와 조용한 퇴직이 기업을 둘러싼 인사 이슈로 떠오르면서, 우수 인재 채용을 위한 기업의 브랜딩 전략과 구성원들이 자부심을 갖고 행복하게 일하는 근무환경 조성이 필수 과제로 떠오르고 있다.',
#  '구성원이 즐겁게 일함으로써 기업이 성장하고, 인재들이 오고 싶은 회사로 발 전하..." ‘Zero 百’ 을 향해 나아가는 실리콘 밸리 HR 연구회 " 미국 캘리포니아의 날씨가 제법 쌀쌀 해지고 사람들은 집집마다 성탄 트리를 준비하기 시작했던',
#  '2022년 12월, 실리콘 밸리 HR 연구회도 올해를 마무리하고 다가오는 2023년을 준비하기 위해 2022년 6차 정기 모임을 가졌다.',
#  '이번 모임은 SK 하이닉스 미주법인 Miss..." 인적자본 확충이 경쟁력의 원천이다 " 인적자원 관리에서 인적자본 경영으로의 이행 최근 일본에서는 인적자원 관리 (Human Resource Management)보다 인적자본 경영 (Human Capital Management)이란 용어가 널리 사용되고 있다.',
#  '인적자본( 人的資本 )이란 인재가 교육이나 연수, 일상 ..." 리세션 시대의 HR " 리세션 (Recession; 경기침체, 불황) 공포가 커지고 있다.',
#  '리세션은 경기가 활기를 잃어 전반적으로 축소되는 현상을 말한다.',
# ...

# %%
ex_nouns = kkma.nouns(doc)
ex_nouns
# Out:
# ['내용',
#  '2023',
#  '2023년',
#  '년',
#  '국내',
#  '기업',
#  '방향',
#  '임직원',
#  '리',
#  '리스킬',
#  '스킬',
#  '업',
#  '업스킬',
#  '필요성',
#  '전망',
#  '경영',
#  '안전',
#  '인권',
#  '윤리',
#  '길',
#  '실리콘',
#  '실리콘밸리',
#  '밸리',
#  '키워드',
#  '퇴사',
#  '시대',
#  '인사',
#  '인사관리',
#  '관리',
#  '기대',
#  '한국',
#  '채용',
#  '채용매력지수',
#  '매력',
#  '지수',
#  '1',
#  '1위',
#  '위',
#  '한국전력',
#  '전력',
#  '동화',
#  '동화기업',
#  '한국중부발전',
#  '중부',
#  '발전',
#  '퇴직',
#  '이슈',
#  '우수',
#  '인재',
#  '브랜딩',
#  '전략',
#  '구성원',
#  '자부심',
#  '행복',
#  '근무',
#  '근무환경',
#  '환경',
#  '조성',
#  '필수',
#  '과제',
#  '성장',
#  '회사',
#  '발',
#  '발전하',
#  '전하',
#  '을',
#  '향',
#  '연구회',
#  '미국',
#  '캘리포니아',
#  '날씨',
#  '사람',
#  '집집',
#  '성탄',
#  '트리',
#  '준비',
#  '시작',
#  '2022',
#  '2022년',
#  '12',
#  '12월',
#  '월',
#  '올해',
#  '마무리',
#  '6',
#  '6차',
#  '차',
#  '정기',
#  '모임',
#  '이번',
#  '하이닉스',
#  '미주',
#  '미주법인',
#  '법인',
#  '인적',
#  '인적자본',
#  '자본',
#  '확충',
#  '경쟁력',
#  '원천',
#  '인적자원',
#  '자원',
#  '이행',
#  '이행최근',
#  '최근',
#  '일본',
# ...

# %%
from re import match  # 전처리 위해서 정규표현식 관련 re 패키지 import
nouns = []

for sent in ex_sent : 
    for noun in kkma.nouns(sent) :
        # 단어 전처리 : 2음절 이상, 수사 제외
        if len(str(noun)) >= 2 and not(match('^[0-9]', noun)) :
            nouns.append(noun)
            
nouns
# Out:
# ['내용',
#  '국내',
#  '기업',
#  '방향',
#  '임직원',
#  '스킬',
#  '필요성',
#  '전망',
#  '경영',
#  '안전',
#  '인권',
#  '윤리',
#  '실리콘',
#  '밸리',
#  '키워드',
#  '퇴사',
#  '시대',
#  '인사',
#  '인사관리',
#  '관리',
#  '기대',
#  '한국',
#  '채용',
#  '매력',
#  '매력지수',
#  '지수',
#  '전력',
#  '동화',
#  '동화기업',
#  '기업',
#  '중부',
#  '발전',
#  '퇴사',
#  '퇴직',
#  '인사',
#  '이슈',
#  '우수',
#  '인재',
#  '브랜딩',
#  '전략',
#  '구성원',
#  '자부심',
#  '행복',
#  '근무',
#  '근무환경',
#  '환경',
#  '조성',
#  '필수',
#  '과제',
#  '구성원',
#  '기업',
#  '성장',
#  '인재',
#  '회사',
#  '전하',
#  '실리콘',
#  '밸리',
#  '연구회',
#  '미국',
#  '캘리포니아',
#  '날씨',
#  '사람',
#  '집집',
#  '성탄',
#  '트리',
#  '준비',
#  '실리콘',
#  '밸리',
#  '연구회',
#  '올해',
#  '마무리',
#  '준비',
#  '정기',
#  '모임',
#  '이번',
#  '모임',
#  '하이닉스',
#  '미주',
#  '미주법인',
#  '법인',
#  '인적',
#  '인적자본',
#  '자본',
#  '확충',
#  '경쟁력',
#  '원천',
#  '인적자원',
#  '자원',
#  '관리',
#  '경영',
#  '이행',
#  '최근',
#  '일본',
#  '용어',
#  '사용',
#  '인적',
#  '인적자본',
#  '자본',
#  '인재',
#  '교육',
#  '연수',
#  '일상',
#  '리세션',
#  '시대',
#  '경기',
#  '경기침체',
# ...

# %%
word_count = {} # 빈 set

# %%
for noun in nouns :
    word_count[noun] = word_count.get(noun, 0) + 1

word_count
# Out:
# {'내용': 4,
#  '국내': 7,
#  '기업': 20,
#  '방향': 3,
#  '임직원': 2,
#  '스킬': 2,
#  '필요성': 1,
#  '전망': 2,
#  '경영': 11,
#  '안전': 1,
#  '인권': 1,
#  '윤리': 1,
#  '실리콘': 4,
#  '밸리': 4,
#  '키워드': 2,
#  '퇴사': 5,
#  '시대': 8,
#  '인사': 12,
#  '인사관리': 2,
#  '관리': 8,
#  '기대': 2,
#  '한국': 7,
#  '채용': 2,
#  '매력': 1,
#  '매력지수': 1,
#  '지수': 1,
#  '전력': 1,
#  '동화': 1,
#  '동화기업': 1,
#  '중부': 1,
#  '발전': 2,
#  '퇴직': 1,
#  '이슈': 3,
#  '우수': 3,
#  '인재': 8,
#  '브랜딩': 1,
#  '전략': 6,
#  '구성원': 8,
#  '자부심': 1,
#  '행복': 3,
#  '근무': 1,
#  '근무환경': 1,
#  '환경': 7,
#  '조성': 1,
#  '필수': 1,
#  '과제': 1,
#  '성장': 2,
#  '회사': 8,
#  '전하': 1,
#  '연구회': 2,
#  '미국': 5,
#  '캘리포니아': 1,
#  '날씨': 1,
#  '사람': 4,
#  '집집': 1,
#  '성탄': 1,
#  '트리': 1,
#  '준비': 4,
#  '올해': 5,
#  '마무리': 1,
#  '정기': 1,
#  '모임': 2,
#  '이번': 3,
#  '하이닉스': 1,
#  '미주': 1,
#  '미주법인': 1,
#  '법인': 1,
#  '인적': 2,
#  '인적자본': 2,
#  '자본': 2,
#  '확충': 1,
#  '경쟁력': 2,
#  '원천': 1,
#  '인적자원': 1,
#  '자원': 1,
#  '이행': 1,
#  '최근': 4,
#  '일본': 5,
#  '용어': 2,
#  '사용': 2,
# ...

# %%
from collections import Counter

counter = Counter(word_count)

top10 = counter.most_common(10)
top10
# Out:
# [('기업', 20),
#  ('인사', 12),
#  ('경영', 11),
#  ('시대', 8),
#  ('관리', 8),
#  ('인재', 8),
#  ('구성원', 8),
#  ('회사', 8),
#  ('국내', 7),
#  ('한국', 7)]

# %% [markdown]
# ## 데이터 시각화

# %%
# data -> nouns 추출

kkma = Kkma() 

ex_nouns = [] # 단어 저장

for sent in crawling_data : # doc -> sentence
    for noun in kkma.nouns(sent) : # sentence -> noun
        ex_nouns.append(noun)

ex_nouns
len(ex_nouns)
# Out:
# 1492

# %%
# 명사 전처리 : 2음절 이상, 숫자 제외 -> 단어사전(dict)
from re import match

nouns_count = {} # 빈 set

for noun in ex_nouns :
    # 2음절 이상, 숫자 제외
    if len(str(noun)) > 1 and not(match('^[0-9]', noun)) :
        nouns_count[noun] = nouns_count.get(noun, 0) + 1

nouns_count
# Out:
# {'국내': 7,
#  '기업': 22,
#  '방향': 3,
#  '임직원': 2,
#  '리스킬': 1,
#  '스킬': 3,
#  '업스킬': 1,
#  '필요성': 1,
#  '전망': 2,
#  '경영': 12,
#  '안전': 1,
#  '인권': 1,
#  '윤리': 1,
#  '실리콘': 4,
#  '실리콘밸리': 4,
#  '밸리': 4,
#  '키워드': 2,
#  '퇴사': 5,
#  '시대': 10,
#  '인사': 12,
#  '인사관리': 2,
#  '관리': 8,
#  '기대': 2,
#  '한국': 6,
#  '채용': 4,
#  '채용매력지수': 1,
#  '매력': 1,
#  '지수': 1,
#  '한국전력': 1,
#  '전력': 1,
#  '동화': 1,
#  '동화기업': 1,
#  '한국중부발전': 1,
#  '중부': 1,
#  '발전': 2,
#  '퇴직': 1,
#  '이슈': 3,
#  '우수': 3,
#  '인재': 12,
#  '브랜딩': 1,
#  '전략': 5,
#  '구성원': 5,
#  '자부심': 1,
#  '행복': 3,
#  '근무': 1,
#  '근무환경': 1,
#  '환경': 6,
#  '조성': 1,
#  '필수': 1,
#  '과제': 1,
#  '성장': 2,
#  '회사': 7,
#  '발전하': 1,
#  '전하': 1,
#  '연구회': 2,
#  '미국': 4,
#  '캘리포니아': 1,
#  '날씨': 1,
#  '사람': 4,
#  '집집': 1,
#  '성탄': 1,
#  '트리': 1,
#  '준비': 3,
#  '시작': 4,
#  '올해': 5,
#  '마무리': 1,
#  '정기': 1,
#  '모임': 1,
#  '이번': 3,
#  '하이닉스': 1,
#  '미주': 1,
#  '미주법인': 1,
#  '법인': 1,
#  '인적': 2,
#  '인적자본': 2,
#  '자본': 2,
#  '확충': 1,
#  '경쟁력': 2,
#  '원천': 1,
# ...

# %%
# 단어 카운트
from collections import Counter

counter = Counter(nouns_count)
top10 = counter.most_common(n=10)
top10
# Out:
# [('기업', 22),
#  ('경영', 12),
#  ('인사', 12),
#  ('인재', 12),
#  ('시대', 10),
#  ('관리', 8),
#  ('국내', 7),
#  ('회사', 7),
#  ('한국', 6),
#  ('환경', 6)]

# %%
# word cloud
import pytagcloud
import webbrowser

# tag에 color, size, tag 사전 구성 
word_count_list = pytagcloud.make_tags(top15, maxsize=100)
# maxsize : 최대 글자크기
print(word_count_list)

pytagcloud.create_tag_image(word_count_list,
                            'newsCrawling2.jpg', 
                            size=(900, 600), 
                            fontname='Noto Sans CJK', rectangular=False)
# Out:
# [{'color': (168, 50, 96), 'size': 122, 'tag': '기업'}, {'color': (118, 14, 155), 'size': 76, 'tag': '경영'}, {'color': (43, 174, 183), 'size': 76, 'tag': '인사'}, {'color': (138, 110, 211), 'size': 76, 'tag': '인재'}, {'color': (37, 173, 160), 'size': 66, 'tag': '시대'}, {'color': (23, 188, 102), 'size': 56, 'tag': '관리'}, {'color': (117, 160, 37), 'size': 50, 'tag': '국내'}, {'color': (10, 162, 13), 'size': 50, 'tag': '회사'}, {'color': (32, 182, 85), 'size': 45, 'tag': '한국'}, {'color': (20, 78, 101), 'size': 45, 'tag': '환경'}, {'color': (22, 21, 51), 'size': 45, 'tag': '변화'}, {'color': (35, 177, 78), 'size': 45, 'tag': '대표'}, {'color': (211, 150, 50), 'size': 39, 'tag': '퇴사'}, {'color': (215, 39, 93), 'size': 39, 'tag': '전략'}, {'color': (146, 178, 182), 'size': 39, 'tag': '구성원'}]
